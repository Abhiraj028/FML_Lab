# %% [markdown]
# KNN

# %%
# !pip install scikit-learn
import os
os.environ["LOKY_MAX_CPU_COUNT"] = "20"
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/lib64/python3.13/site-packages (from scikit-learn) (2.2.6)
# Collecting scipy>=1.8.0 (from scikit-learn)
#   Downloading scipy-1.16.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (61 kB)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.7.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 1.9 MB/s eta 0:00:001.9 MB/s eta 0:00:010m
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading scipy-1.16.1-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (35.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 1.9 MB/s eta 0:00:00m eta 0:00:010:01:02
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.1 scikit-learn-1.7.1 scipy-1.16.1 threadpoolctl-3.6.0

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.datasets import load_iris

# %%
from sklearn.model_selection import train_test_split

# %%
iris = load_iris()

# %%
X_train,X_test,y_train,y_test = train_test_split(iris.data,iris.target,test_size=0.3,random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = knn.score(X_test,y_test)

# %%
print("Accuracy:",accuracy)
# Out:
# Accuracy: 1.0

# %% [markdown]
# CNN

# %%
# !pip install imbalanced-learn
from imblearn.under_sampling import CondensedNearestNeighbour
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: imbalanced-learn in /home/abhiraj/.local/lib/python3.13/site-packages (0.13.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /usr/lib64/python3.13/site-packages (from imbalanced-learn) (2.2.6)
# Requirement already satisfied: scipy<2,>=1.10.1 in /home/abhiraj/.local/lib/python3.13/site-packages (from imbalanced-learn) (1.16.1)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /home/abhiraj/.local/lib/python3.13/site-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /home/abhiraj/.local/lib/python3.13/site-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /home/abhiraj/.local/lib/python3.13/site-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /home/abhiraj/.local/lib/python3.13/site-packages (from imbalanced-learn) (3.6.0)
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[26], line 2
#       1 get_ipython().system('pip install imbalanced-learn')
# ----> 2 from imblearn.under_sampling import CondensedNearestNeighbour
#
# File ~/.local/lib/python3.13/site-packages/imblearn/__init__.py:52
#      48     sys.stderr.write("Partial import of imblearn during the build process.\n")
#      49     # We are not importing the rest of scikit-learn during the build
#      50     # process, as it may not be compiled yet
#      51 else:
# ---> 52     from . import (
#      53         combine,
#      54         ensemble,
#      55         exceptions,
#      56         metrics,
#      57         over_sampling,
#      58         pipeline,
#      59         tensorflow,
#      60         under_sampling,
#      61         utils,
#      62     )
#      63     from ._version import __version__
#      64     from .base import FunctionSampler
#
# File ~/.local/lib/python3.13/site-packages/imblearn/combine/__init__.py:5
#       1 """The :mod:`imblearn.combine` provides methods which combine
#       2 over-sampling and under-sampling.
#       3 """
# ----> 5 from ._smote_enn import SMOTEENN
#       6 from ._smote_tomek import SMOTETomek
#       8 __all__ = ["SMOTEENN", "SMOTETomek"]
#
# File ~/.local/lib/python3.13/site-packages/imblearn/combine/_smote_enn.py:12
#       9 from sklearn.base import clone
#      10 from sklearn.utils import check_X_y
# ---> 12 from ..base import BaseSampler
#      13 from ..over_sampling import SMOTE
#      14 from ..over_sampling.base import BaseOverSampler
#
# File ~/.local/lib/python3.13/site-packages/imblearn/base.py:15
#      12 from sklearn.utils._metadata_requests import METHODS
#      13 from sklearn.utils.multiclass import check_classification_targets
# ---> 15 from .utils import check_sampling_strategy, check_target_type
#      16 from .utils._sklearn_compat import _fit_context, get_tags, validate_data
#      17 from .utils._validation import ArraysTransformer
#
# File ~/.local/lib/python3.13/site-packages/imblearn/utils/__init__.py:6
#       1 """
#       2 The :mod:`imblearn.utils` module includes various utilities.
#       3 """
#       5 from ._docstring import Substitution
# ----> 6 from ._validation import (
#       7     check_neighbors_object,
#       8     check_sampling_strategy,
#       9     check_target_type,
#      10 )
#      12 __all__ = [
#      13     "check_neighbors_object",
#      14     "check_sampling_strategy",
#      15     "check_target_type",
#      16     "Substitution",
#      17 ]
#
# File ~/.local/lib/python3.13/site-packages/imblearn/utils/_validation.py:20
#      17 from sklearn.utils.multiclass import type_of_target
#      18 from sklearn.utils.validation import _num_samples
# ---> 20 from ..utils._sklearn_compat import _is_pandas_df, check_array
#      22 SAMPLING_KIND = (
#      23     "over-sampling",
#      24     "under-sampling",
#    (...)     27     "bypass",
#      28 )
#      29 TARGET_KIND = ("binary", "multiclass", "multilabel-indicator")
#
# File ~/.local/lib/python3.13/site-packages/imblearn/utils/_sklearn_compat.py:815
#     811 @dataclass(**_dataclass_args())
#     812 class Tags(Tags):
#     813     sampler_tags: SamplerTags | None = None
# --> 815 from sklearn.utils._test_common.instance_generator import (
#     816     _construct_instances,  # noqa: F401
#     817 )
#     818 from sklearn.utils.estimator_checks import (
#     819     check_estimator,  # noqa: F401
#     820     parametrize_with_checks,  # noqa: F401
#     821 )
#     822 from sklearn.utils.multiclass import type_of_target  # noqa: F401
#
# File ~/.local/lib/python3.13/site-packages/sklearn/utils/_test_common/instance_generator.py:13
#      11 from sklearn import clone, config_context
#      12 from sklearn.calibration import CalibratedClassifierCV
# ---> 13 from sklearn.cluster import (
#      14     HDBSCAN,
#      15     AffinityPropagation,
#      16     AgglomerativeClustering,
#      17     Birch,
#      18     BisectingKMeans,
#      19     FeatureAgglomeration,
#      20     KMeans,
#      21     MeanShift,
#      22     MiniBatchKMeans,
#      23     SpectralBiclustering,
#      24     SpectralClustering,
#      25     SpectralCoclustering,
#      26 )
#      27 from sklearn.compose import ColumnTransformer
#      28 from sklearn.covariance import GraphicalLasso, GraphicalLassoCV
#
# File ~/.local/lib/python3.13/site-packages/sklearn/cluster/__init__.py:7
#       3 # Authors: The scikit-learn developers
#       4 # SPDX-License-Identifier: BSD-3-Clause
#       6 from ._affinity_propagation import AffinityPropagation, affinity_propagation
# ----> 7 from ._agglomerative import (
#       8     AgglomerativeClustering,
#       9     FeatureAgglomeration,
#      10     linkage_tree,
#      11     ward_tree,
#      12 )
#      13 from ._bicluster import SpectralBiclustering, SpectralCoclustering
#      14 from ._birch import Birch
#
# File ~/.local/lib/python3.13/site-packages/sklearn/cluster/_agglomerative.py:44
#      42 # mypy error: Module 'sklearn.cluster' has no attribute '_hierarchical_fast'
#      43 from . import _hierarchical_fast as _hierarchical  # type: ignore
# ---> 44 from ._feature_agglomeration import AgglomerationTransform
#      46 ###############################################################################
#      47 # For non fully-connected graphs
#      50 def _fix_connectivity(X, connectivity, affinity):
#
# File ~/.local/lib/python3.13/site-packages/sklearn/cluster/_feature_agglomeration.py:15
#      13 from ..base import TransformerMixin
#      14 from ..utils import metadata_routing
# ---> 15 from ..utils.deprecation import _deprecate_Xt_in_inverse_transform
#      16 from ..utils.validation import check_is_fitted, validate_data
#      18 ###############################################################################
#      19 # Mixin class for feature agglomeration.
#
# ImportError: cannot import name '_deprecate_Xt_in_inverse_transform' from 'sklearn.utils.deprecation' (/home/abhiraj/.local/lib/python3.13/site-packages/sklearn/utils/deprecation.py)

# %%
from sklearn.datasets import make_classification

# %%
X,y = make_classification(n_samples=1000,n_classes=2,weights=[0.9,0.1],random_state=42)

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3,random_state = 42)

# %%
cnn = CondensedNearestNeighbour(random_state=42)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 cnn = CondensedNearestNeighbour(random_state=42)
#
# NameError: name 'CondensedNearestNeighbour' is not defined

# %%
X_res,y_res = cnn.fit_resample(X_train,y_train)

# %%
knn = KNeighborsClassifier(n_neighbors = 5)

# %%
knn.fit(X_res,y_res)
# Out:
# KNeighborsClassifier()

# %%
y_pred = knn.predict(X_test)

# %%
accuracy = knn.score(X_test,y_test)

# %%
print("Accuracy: ",accuracy)
# Out:
# Accuracy:  0.8833333333333333
