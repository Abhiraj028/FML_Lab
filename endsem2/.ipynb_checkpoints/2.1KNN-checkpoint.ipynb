# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_digits, make_classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, roc_auc_score, RocCurveDisplay, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

digit = load_digits()

digit.data, digit.target = make_classification(n_samples= 1000, n_features= 5, n_classes=2, random_state=42)
X_train, X_test, y_train, y_test = train_test_split(digit.data, digit.target,test_size=0.3,random_state=42)

knn = KNeighborsClassifier(n_neighbors=5, metric="manhattan")
knn.fit(X_train,y_train)

y_pred = knn.predict(X_test)

Accuracy = accuracy_score(y_test,y_pred)
Precision = precision_score(y_test,y_pred, average='macro')
Recall = recall_score(y_test, y_pred, average='macro')
F1 = f1_score(y_test,y_pred, average='macro')

print("Accuracy: ",Accuracy)
print("Precision:",Precision)
print("Recall:",Recall)
print("F1:",F1)
print("\n")

print("Classification Report: ",classification_report(y_test,y_pred))

y_probs = knn.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_test,y_probs)
print("AUC: ",auc)

RocCurveDisplay.from_estimator(knn,X_test,y_test)
plt.title("ROC Curve")
plt.show()

ConfusionMatrixDisplay.from_estimator(knn,X_test,y_test)
plt.title("Confusion Matrix")
plt.show()
# Out:
# Accuracy:  0.89
# Precision: 0.8922119630670413
# Recall: 0.8910780999822095
# F1: 0.8899694359544318
#
#
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       146
#            1       0.93      0.85      0.89       154
#
#     accuracy                           0.89       300
#    macro avg       0.89      0.89      0.89       300
# weighted avg       0.89      0.89      0.89       300
#
# AUC:  0.9440491015833482

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.datasets import load_digits, make_classification
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report, roc_auc_score, RocCurveDisplay, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
digit = load_digits()

# %%
digit.data, digit.target = make_classification(n_samples= 1000, n_features= 5, n_classes=2, random_state=42)

# %%
X_train, X_test, y_train, y_test = train_test_split(digit.data, digit.target,test_size=0.3,random_state=42)

# %%
knn = KNeighborsClassifier(n_neighbors=5, metric="manhattan")
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(metric='manhattan')

# %%
y_pred = knn.predict(X_test)

# %%
Accuracy = accuracy_score(y_test,y_pred)
Precision = precision_score(y_test,y_pred, average='macro')
Recall = recall_score(y_test, y_pred, average='macro')
F1 = f1_score(y_test,y_pred, average='macro')

# %%
print("Accuracy: ",Accuracy)
print("Precision:",Precision)
print("Recall:",Recall)
print("F1:",F1)
print("\n")
# Out:
# Accuracy:  0.89
# Precision: 0.8922119630670413
# Recall: 0.8910780999822095
# F1: 0.8899694359544318

# %%
print("Classification Report: ",classification_report(y_test,y_pred))
# Out:
# Classification Report:                precision    recall  f1-score   support
#
#            0       0.86      0.93      0.89       146
#            1       0.93      0.85      0.89       154
#
#     accuracy                           0.89       300
#    macro avg       0.89      0.89      0.89       300
# weighted avg       0.89      0.89      0.89       300

# %%
y_probs = knn.predict_proba(X_test)[:,1]
auc = roc_auc_score(y_test,y_probs)
print("AUC: ",auc)
# Out:
# AUC:  0.9440491015833482

# %%
RocCurveDisplay.from_estimator(knn,X_test,y_test)
plt.title("ROC Curve")
plt.show()

# %%
ConfusionMatrixDisplay.from_estimator(knn,X_test,y_test)
plt.title("Confusion Matrix")
plt.show()
