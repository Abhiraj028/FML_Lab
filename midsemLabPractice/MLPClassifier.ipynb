# %%
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import *
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split

# %%
iris = load_breast_cancer()

# %%
X_train,X_test,y_train,y_test = train_test_split(iris.data,iris.target,test_size=0.3,random_state=42)

# %%
percept = MLPClassifier(hidden_layer_sizes=(10,),max_iter=10000,activation="logistic")

# %%
percept.fit(X_train,y_train)
# Out:
# MLPClassifier(activation='logistic', hidden_layer_sizes=(10,), max_iter=10000)

# %%
y_pred = percept.predict(X_test)

# %%
Accuracy = accuracy_score(y_test,y_pred)
Precision = precision_score(y_test,y_pred, average="macro")
F1 = f1_score(y_test,y_pred, average= "macro")
Recall = recall_score(y_test,y_pred,average = "macro")

# %%
print(f"""
Accuracy:{Accuracy}
Precision:{Precision}
Recall:{Recall}
F1:{F1}""")
# Out:
# Accuracy:0.9707602339181286
# Precision:0.9736486486486486
# Recall:0.9636243386243386
# F1:0.9682592716338122

# %%
import sys
# !{sys.executable} -m pip install matplotlib
import matplotlib.pyplot as plt
y_probs = percept.predict_proba(X_test)[:,1]
fpr,tpr,_ = roc_curve(y_test,y_probs)
plt.plot(fpr,tpr)
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in /home/abhiraj/.local/lib/python3.13/site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in /home/abhiraj/.local/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /home/abhiraj/.local/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/abhiraj/.local/lib/python3.13/site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /home/abhiraj/.local/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in /usr/lib64/python3.13/site-packages (from matplotlib) (2.2.6)
# Requirement already satisfied: packaging>=20.0 in /usr/lib/python3.13/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/lib64/python3.13/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/abhiraj/.local/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/lib/python3.13/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
